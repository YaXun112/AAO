# %% [markdown]
# <a href="https://colab.research.google.com/github/YaXun112/Colab/blob/DL/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
import os

Dataset_File = "WeatherData.csv"
if not os.path.isfile(Dataset_File):
  os.system("wget https://raw.githubusercontent.com/cnchi/datasets/master/" + Dataset_File)

# %%
dfCSV = pd.read_csv("WeatherData.csv")
print(dfCSV)
# Out:
#     觀測日期(day)  當日氣壓(hPa)  氣溫(℃)  相對溼度(%)  風速(m/s)  降水量(mm)
# 0           1      996.3   25.7       90      0.3      6.5
# 1           2     1001.1   28.2       80      0.6      0.0
# 2           3     1005.1   28.2       79      1.3      4.0
# 3           4     1005.9   27.0       86      0.6     91.5
# 4           5     1005.2   27.7       84      0.3      7.0
# 5           6     1004.8   28.3       79      0.4      0.0
# 6           7     1005.8   27.7       84      0.6      1.0
# 7           8     1003.6   29.0       79      0.6      0.0
# 8           9     1001.3   26.5       90      0.6     40.0
# 9          10      999.1   25.6       91      0.4     53.5
# 10         11      998.9   25.4       92      0.2      4.0
# 11         12      999.4   25.5       84      0.9      0.5
# 12         13      998.6   26.4       77      1.5      0.0
# 13         14     1001.3   26.3       83      0.9      1.5
# 14         15     1004.9   24.5       89      1.1     22.5
# ...

# %%
ary = dfCSV.to_numpy()
print(ary.T)
# Out:
# [[1.0000e+00 2.0000e+00 3.0000e+00 4.0000e+00 5.0000e+00 6.0000e+00
#   7.0000e+00 8.0000e+00 9.0000e+00 1.0000e+01 1.1000e+01 1.2000e+01
#   1.3000e+01 1.4000e+01 1.5000e+01 1.6000e+01 1.7000e+01 1.8000e+01
#   1.9000e+01 2.0000e+01 2.1000e+01 2.2000e+01 2.3000e+01 2.4000e+01
#   2.5000e+01 2.6000e+01 2.7000e+01 2.8000e+01 2.9000e+01 3.0000e+01]
#  [9.9630e+02 1.0011e+03 1.0051e+03 1.0059e+03 1.0052e+03 1.0048e+03
#   1.0058e+03 1.0036e+03 1.0013e+03 9.9910e+02 9.9890e+02 9.9940e+02
#   9.9860e+02 1.0013e+03 1.0049e+03 1.0057e+03 1.0071e+03 1.0053e+03
#   1.0026e+03 1.0017e+03 1.0024e+03 1.0035e+03 1.0048e+03 1.0055e+03
#   1.0061e+03 1.0060e+03 1.0069e+03 1.0065e+03 1.0041e+03 1.0031e+03]
#  [2.5700e+01 2.8200e+01 2.8200e+01 2.7000e+01 2.7700e+01 2.8300e+01
#   2.7700e+01 2.9000e+01 2.6500e+01 2.5600e+01 2.5400e+01 2.5500e+01
#   2.6400e+01 2.6300e+01 2.4500e+01 2.5700e+01 2.6400e+01 2.8600e+01
#   2.8700e+01 3.0000e+01 3.0100e+01 2.9300e+01 2.7300e+01 2.7400e+01
# ...

# %%
DTem = ary.T[2]

# %%
dfCSV.describe(include='all')
# Out:
#        觀測日期(day)    當日氣壓(hPa)      氣溫(℃)    相對溼度(%)    風速(m/s)    降水量(mm)
# count  30.000000    30.000000  30.000000  30.000000  30.000000  30.000000
# mean   15.500000  1003.420000  27.566667  82.466667   0.553333  11.933333
# std     8.803408     2.844644   1.486568   5.929083   0.333976  22.894712
# min     1.000000   996.300000  24.500000  73.000000   0.000000   0.000000
# 25%     8.250000  1001.400000  26.400000  78.250000   0.300000   0.000000
# 50%    15.500000  1004.450000  27.700000  82.000000   0.450000   0.500000
# 75%    22.750000  1005.650000  28.675000  86.750000   0.600000   8.125000
# max    30.000000  1007.100000  30.100000  93.000000   1.500000  91.500000

# %%
print('平均氣溫：',dfCSV['氣溫(℃)'].mean(),'℃')
print('最大濕度：',dfCSV['相對溼度(%)'].max(),'%')
print('最低氣壓：',dfCSV['當日氣壓(hPa)'].min(),'hPa')
print('總雨量：',dfCSV['降水量(mm)'].sum(),'mm')
# Out:
# 平均氣溫： 27.566666666666666 ℃
# 最大濕度： 93 %
# 最低氣壓： 996.3 hPa
# 總雨量： 358.0 mm

# %%
# X 軸資料製作
X = np.arange(0., 30., 1)

# 繪製折線圖
X = np.arange(0., 30., 1)
plt.plot(X, DTem, "r-")
plt.show()
